# %%
import pandas as pd
from ddf_presched_desc import generate_ddf_scheduled_obs

# %%
ddf_visits = generate_ddf_scheduled_obs()
# Out:
# Optimizing ELAISS1
# Optimizing XMM_LSS
# Optimizing ECDFS
# Optimizing COSMOS
# Optimizing EDFS_a

# %%
pd.DataFrame(ddf_visits)
# Out:
#         ID        RA       dec           mjd  flush_by_mjd  exptime band  \
# 0        0  0.164934 -0.768381  60985.012500  60987.012500     30.0    u
# 1        0  0.164934 -0.768381  60985.012500  60987.012500     30.0    u
# 2        0  0.164934 -0.768381  60985.012500  60987.012500     30.0    u
# 3        0  0.164934 -0.768381  60985.012500  60987.012500     30.0    u
# 4        0  0.164934 -0.768381  60985.012500  60987.012500     30.0    u
# ...     ..       ...       ...           ...           ...      ...  ...
# 200295   0  1.110029 -0.830777  64630.252082  64632.252082     30.0    y
# 200296   0  1.110029 -0.830777  64630.252082  64632.252082     30.0    y
# 200297   0  1.110029 -0.830777  64630.252082  64632.252082     30.0    y
# 200298   0  1.110029 -0.830777  64630.252082  64632.252082     30.0    y
# 200299   0  1.110029 -0.830777  64630.252082  64632.252082     30.0    y
#
#        filter  rotSkyPos  rotTelPos  ...  observation_reason   mjd_tol  \
# ...
