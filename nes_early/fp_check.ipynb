# %%
import numpy as np
import matplotlib.pylab as plt
# %matplotlib inline
from template_bfs import LowNesMap
from rubin_scheduler.scheduler.utils import CurrentAreaMap
import healpy as hp

# %%
lnm = LowNesMap()
ev, sm, labels = lnm.estimate_visits(1.9e6)

# %%
hp.mollview(ev['g'])

# %%
np.unique(ev['g'])
# Out:
# array([  0.        ,  32.59722876,  44.55389228,  48.43016845,
#         74.50795146, 121.07542113, 173.23098715])

# %%
lnm = CurrentAreaMap()
ev, sm, labels = lnm.estimate_visits(1.9e6)

# %%
np.unique(ev['g'])
# Out:
# array([  0.        ,  32.58085812,  47.47496469,  48.40584635,
#         74.47053284, 121.01461587, 173.14398885])
