# %%
import sqlite3 
import numpy as np
import pandas as pd
import matplotlib.pylab as plt
# %matplotlin inline
# Out:
# UsageError: Line magic function `%matplotlin` not found.

# %%
con = sqlite3.connect("baseline_v4.3.1_10yrs.db")
data = pd.read_sql("select fivesigmadepth,moonAlt from observations where filter='g' and visitExposureTime > 25;", con)
con.close()

# %%
_tmp = plt.hist(data["fiveSigmaDepth"], bins=50)

# %%
plt.scatter(data["moonAlt"], data["fiveSigmaDepth"], alpha=0.5)
